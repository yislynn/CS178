# %% [markdown]
# # Problem 1: Python and Data Exploration #

# %%
import numpy as np
import matplotlib.pyplot as plt

iris = np.genfromtxt("data/iris.txt",delimiter=None)
Y = iris[:,-1]
X = iris[:,0:-1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18776/3401524974.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 iris = np.genfromtxt("data/iris.txt",delimiter=None)
#       5 Y = iris[:,-1]
#       6 X = iris[:,0:-1]
#
# c:\python38\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1811             fname = os_fspath(fname)
#    1812         if isinstance(fname, str):
# -> 1813             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1814             fid_ctx = contextlib.closing(fid)
#    1815         else:
#
# ...

# %%
print(X.shape)

# %% [markdown]
# ### 1.1

# %% [markdown]
# After running the program and calling X.shape in the Python Shell, I got (148, 4). 148 is the number of data pointsstarting from the first data point to the second-to-last data point (as the selection X stops right before the last value--from 0 to -1). 4 is the number of features.

# %% [markdown]
# ### 1.2

# %% [markdown]
# Y contains the targets of the data set. To plot a histogram for each feature per groups, the data must be separated into their respective groups.

# %% [markdown]
# ### 1.3

# %%
np.mean(X, axis=0)
np.std(X, axis=0)
np.max(X, axis=0)
np.min(X, axis=0)

# %% [markdown]
# Results of the previous calls, respectively:
# array([5.90010376, 3.09893092, 3.81955484, 1.25255548])
# array([0.83340207, 0.43629184, 1.75405711, 0.75877246])
# array([7.9528335, 4.458073 , 6.9347277, 2.5771235])
# array([4.3265579 , 2.0020454 , 1.0238316 , 0.12509037])

# %% [markdown]
# ### 1.4

# %% [markdown]
# # Problem 2: Basic Linear Algebra

# %% [markdown]
# 1. A matrix has an inverse when it is square and its determinant is not 0.

# %% [markdown]
# 2. Determinants of A and B

# %% [markdown]
# ![cs178%20hw1%202.1%20img-2.png](attachment:cs178%20hw1%202.1%20img-2.png)

# %% [markdown]
# 3. Inverses of A and B

# %% [markdown]
# ![cs178%20hw1%202.2%20A.png](attachment:cs178%20hw1%202.2%20A.png)

# %% [markdown]
# ![cs178%20hw1%202.2%20B.png](attachment:cs178%20hw1%202.2%20B.png)

# %% [markdown]
# 4. Inverses of the transposes of A and B

# %% [markdown]
# ![cs178%20hw1%202.4.png](attachment:cs178%20hw1%202.4.png)

# %% [markdown]
# 5. C = AB. The inverse of C

# %% [markdown]
# ![cs178%20hw1%202.5.png](attachment:cs178%20hw1%202.5.png)

# %% [markdown]
# # Problem 3: kNN Predictions

# %% [markdown]
# # Problem 4:  Conditional, Marginal, and Posterior Probabilities

# %% [markdown]
# 1. Estimate p(y) for y = -1, 1; estimate p(xi|y) for each class y and feature xi (xi = 0, 1)

# %% [markdown]
# ![problem4_1.jpg](attachment:problem4_1.jpg)

# %% [markdown]
# 2. p(x-bar|y) for x-bar = (0 0 1 1 0), (1 1 1 1 0) and y = 1, -1

# %% [markdown]
# ![problem4_2.jpg](attachment:problem4_2.jpg)

# %% [markdown]
# 3. Posterior probability p(y = 1|x-bar = (0 0 1 1 0))

# %% [markdown]
# ![problem4_3.jpg](attachment:problem4_3.jpg)

# %% [markdown]
# # Statement of Collaboration

# %% [markdown]
# I did not collaborate with anyone on the problems for this homework.
